# %% [markdown]
# # 第六次程式作業

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

x = np.linspace(-10, 10, 50)
y = np.linspace(-10, 10, 50)

x, y = np.meshgrid(x,y)

x = x.flatten()
y = y.flatten()

plt.scatter(x,y)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
# Out:
# (-10, 10)
